# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns=['cgpa','resume_score','LPA'])

# %%
df
# Out:
#    cgpa  resume_score  LPA
# 0     8             8    4
# 1     7             9    5
# 2     6            10    6
# 3     5            12    7

# %%
#architecture forming
def initialize_parameters(layer_dims):

  np.random.seed(3)
  parameters = {}
  L = len(layer_dims)

  for l in range(1, L):

    parameters['W' + str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
    parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))


  return parameters

# %%
initialize_parameters([2,2,1])
# Out:
# {'W1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
#utility function
def sigmoid(Z):

  A=1/(1+np.exp(-Z))
  return A

# %%
#Params for forward propagation
def linear_forward(A_prev,W,b):
  z=np.dot(W.T,A_prev)+b
  A=sigmoid(z)

  return A

# %%
#forward propagation
def L_layer_forward(X,parameters):

  A=X
  L=len(parameters)//2

  for l in range(1,L+1):
    A_prev=A
    Wl=parameters['W'+str(l)]
    bl=parameters['b'+str(l)]
    #print("A"+str(l-1)+": ", A_prev)
    #print("W"+str(l)+": ", Wl)
    #print("b"+str(l)+": ", bl)
    #print("--"*20)

    A=linear_forward(A_prev,Wl,bl)
    #print("A"+str(l)+": ", A)
    #print("**"*20)

  return A,A_prev

# %%
X = df[['cgpa','resume_score']].values[0].reshape(2,1)
y=df[['LPA']].values[0][0]

#params initialization
parameters=initialize_parameters([2,2,1])

y_hat,A1=L_layer_forward(X,parameters)

# %%
y_hat=y_hat[0][0]
A1
# Out:
# array([[1.6],
#        [1.6]])

# %%
def update_parameters(parameters,y,y_hat,A1,X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat)*A1[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat)*A1[1][0])
  parameters['b2'][0][0] = parameters['W2'][1][0] + (0.001 * 2 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0]*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][0][0])

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0]*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001 * 2 * (y - y_hat)*parameters['W2'][1][0])

# %%
update_parameters(parameters,y,y_hat,A1,X)

# %%
parameters
# Out:
# {'W1': array([[0.10658137, 0.10658137],
#         [0.10658137, 0.10658137]]),
#  'b1': array([[0.00082267],
#         [0.00082267]]),
#  'W2': array([[0.111776],
#         [0.111776]]),
#  'b2': array([[0.119136]])}

# %%
X = df[['cgpa', 'resume_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['LPA']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# {'W1': array([[0.10585205, 0.10585205],
#         [0.10585205, 0.10585205]]),
#  'b1': array([[0.00073151],
#         [0.00073151]]),
#  'W2': array([[0.10575506],
#         [0.10575506]]),
#  'b2': array([[0.11267205]])}

# %%
X = df[['cgpa', 'resume_score']].values[1].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['LPA']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[7]
#  [9]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[0.83201839]
#  [0.83201839]]
# ****************************************
# A1:  [[0.83201839]
#  [0.83201839]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.54150519]]
# ****************************************
# {'W1': array([[0.10512055, 0.10658356],
#         [0.10512055, 0.10658356]]),
#  'b1': array([[0.00073151],
#         [0.00073151]]),
#  'W2': array([[0.10575506],
#         [0.10575506]]),
#  'b2': array([[0.11267205]])}

# %%
X = df[['cgpa', 'resume_score']].values[3].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['LPA']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat,A1 = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,A1,X)

parameters
# Out:
# A0:  [[ 5]
#  [12]]
# W1:  [[0.1 0.1]
#  [0.1 0.1]]
# b1:  [[0.]
#  [0.]]
# ----------------------------------------
# A1:  [[0.84553473]
#  [0.84553473]]
# ****************************************
# A1:  [[0.84553473]
#  [0.84553473]]
# W2:  [[0.1]
#  [0.1]]
# b2:  [[0.]]
# ----------------------------------------
# A2:  [[0.54217627]]
# ****************************************
# {'W1': array([[0.10366002, 0.10878404],
#         [0.10366002, 0.10878404]]),
#  'b1': array([[0.000732],
#         [0.000732]]),
#  'W2': array([[0.10584742],
#         [0.10584742]]),
#  'b2': array([[0.11276307]])}

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 50

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'resume_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['LPA']].values[j][0]

    # Parameter initialization


    y_hat,A1 = L_layer_forward(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,A1,X)

    Loss.append(-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

  print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# Epoch -  1 Loss -  -0.7781557461281756
# Epoch -  2 Loss -  -1.4333432929028298
# Epoch -  3 Loss -  -2.019795409067582
# Epoch -  4 Loss -  -2.6042959238861845
# Epoch -  5 Loss -  -3.1759932283895687
# Epoch -  6 Loss -  -3.7354069079698817
# Epoch -  7 Loss -  -4.2856538711011485
# Epoch -  8 Loss -  -4.829138893744716
# Epoch -  9 Loss -  -5.367230852599636
# Epoch -  10 Loss -  -5.9006670683991125
# Epoch -  11 Loss -  -6.42989915202789
# Epoch -  12 Loss -  -6.955269904641326
# Epoch -  13 Loss -  -7.477081411146506
# Epoch -  14 Loss -  -7.995615433163097
# Epoch -  15 Loss -  -8.511137895179191
# Epoch -  16 Loss -  -9.023899331983431
# Epoch -  17 Loss -  -9.534134711193511
# Epoch -  18 Loss -  -10.04206338534961
# Epoch -  19 Loss -  -10.547889271548222
# Epoch -  20 Loss -  -11.051801228911275
# Epoch -  21 Loss -  -11.553973588524725
# Epoch -  22 Loss -  -12.054566794266991
# Epoch -  23 Loss -  -12.553728119270502
# Epoch -  24 Loss -  -13.051592428920413
# Epoch -  25 Loss -  -13.548282966857885
# Epoch -  26 Loss -  -14.043912145337522
# Epoch -  27 Loss -  -14.538582325486843
# Epoch -  28 Loss -  -15.032386576564276
# Epoch -  29 Loss -  -15.525409406263895
# Epoch -  30 Loss -  -16.01772745653531
# Epoch -  31 Loss -  -16.509410161340302
# Epoch -  32 Loss -  -17.00052036432279
# Epoch -  33 Loss -  -17.49111489558391
# Epoch -  34 Loss -  -17.981245107687666
# Epoch -  35 Loss -  -18.4709573717228
# Epoch -  36 Loss -  -18.960293534757433
# Epoch -  37 Loss -  -19.449291340380682
# Epoch -  38 Loss -  -19.937984814260822
# Epoch -  39 Loss -  -20.426404616791263
# Epoch -  40 Loss -  -20.9145783649598
# Epoch -  41 Loss -  -21.402530925587584
# Epoch -  42 Loss -  -21.890284682051018
# Epoch -  43 Loss -  -22.377859776536724
# Epoch -  44 Loss -  -22.86527432979341
# Epoch -  45 Loss -  -23.352544640247714
# Epoch -  46 Loss -  -23.839685364239635
# Epoch -  47 Loss -  -24.326709679023583
# Epoch -  48 Loss -  -24.81362943006601
# Epoch -  49 Loss -  -25.300455264057742
# Epoch -  50 Loss -  -25.787196748951914
# {'W1': array([[11.68554379, 18.97633436],
#         [11.71913584, 19.0309455 ]]),
#  'b1': array([[1.8646185 ],
#         [1.87001843]]),
#  'W2': array([[1.92816897],
#         [1.93126214]]),
#  'b2': array([[1.94326839]])}

# %% [markdown]
# Using keras

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential

# %%
df
# Out:
#    cgpa  resume_score  LPA
# 0     8             8    4
# 1     7             9    5
# 2     6            10    6
# 3     5            12    7

# %%
X=df[['cgpa', 'resume_score']]
y=df['LPA']

# %%
model = Sequential()
model.add(keras.layers.Dense(2,activation='sigmoid',input_dim=2))
model.add(keras.layers.Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy',optimizer=optimizer)

# %%
model.fit(df.iloc[:,0:-1].values,df['LPA'].values,epochs=50,verbose=1,batch_size=1)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 2.2345
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0196
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1676
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0593
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9261
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9405
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9510
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8542
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7303
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7401
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5548
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5370
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4561
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3919
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3132
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2132
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1469
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0573
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9481
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8724
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8347
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6458
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6651
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6011
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4910
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4373
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1389
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1760
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0700
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0972
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.0046
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.3433
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3454
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.4420
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.3247
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.5843
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -0.9330
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: -0.9961
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.1364
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.0992
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -0.8870
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4011
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4794
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.3186
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.4829
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1.6876
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.8754
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.9691
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: -1.7438
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1.8713
